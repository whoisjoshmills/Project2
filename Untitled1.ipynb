# %%
import pandas as pd

# %%
plane_df =  pd.read_csv('data/take_2.csv')
plane_df.head()
# Out:
#         Date   Time       location   Latitude      long  \
# 0  7/12/1912   6:30  Atlantic City  39.360600  -74.4319
# 1   8/6/1913    NaN       Victoria  48.427500 -123.3673
# 2   9/9/1913  18:30      North Sea  40.940556  -72.4031
# 3   3/5/1915   1:00         Tienen  50.805500    4.9394
# 4  9/24/1916   1:00     Billericay  51.630100    0.4212
#
#                  Operator Flight #        Route                     Type  \
# 0    Military - U.S. Navy      NaN  Test flight                Dirigible
# 1                 Private        -          NaN         Curtiss seaplane
# 2  Military - German Navy      NaN          NaN   Zeppelin L-1 (airship)
# 3  Military - German Navy      NaN          NaN   Zeppelin L-8 (airship)
# 4  Military - German Navy      NaN          NaN  Zeppelin L-32 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN   NaN     5.0         5.0     0.0
# 1          NaN   NaN     1.0         1.0     0.0
# ...

# %%
plane_df.fillna(0)
# Out:
#            Date   Time       location   Latitude      long  \
# 0     7/12/1912   6:30  Atlantic City  39.360600  -74.4319
# 1      8/6/1913      0       Victoria  48.427500 -123.3673
# 2      9/9/1913  18:30      North Sea  40.940556  -72.4031
# 3      3/5/1915   1:00         Tienen  50.805500    4.9394
# 4     9/24/1916   1:00     Billericay  51.630100    0.4212
# ...         ...    ...            ...        ...       ...
# 2494  2/15/2009  16:05         Chanco -35.737400  -72.5337
# 2495  2/20/2009   4:10          Luxor  25.683300   32.6500
# 2496  2/25/2009  10:31      Amsterdam  52.373200    4.8907
# 2497  3/22/2009  14:28          Butte  46.012800 -112.5356
# 2498   4/6/2009  12:30        Bandung  -6.914700  107.6098
#
#                              Operator  Aboard  Fatalities
# 0                Military - U.S. Navy     5.0         5.0
# 1                             Private     1.0         1.0
# 2              Military - German Navy    20.0        14.0
# ...

# %%
del plane_df['Flight #']
del plane_df['Route']
del plane_df['Type']
del plane_df['Registration']
del plane_df['cn/In']
del plane_df['Ground']
del plane_df['Summary']

# %%
plane_df.head()
# Out:
#         Date   Time       location   Latitude      long  \
# 0  7/12/1912   6:30  Atlantic City  39.360600  -74.4319
# 1   8/6/1913    NaN       Victoria  48.427500 -123.3673
# 2   9/9/1913  18:30      North Sea  40.940556  -72.4031
# 3   3/5/1915   1:00         Tienen  50.805500    4.9394
# 4  9/24/1916   1:00     Billericay  51.630100    0.4212
#
#                  Operator  Aboard  Fatalities
# 0    Military - U.S. Navy     5.0         5.0
# 1                 Private     1.0         1.0
# 2  Military - German Navy    20.0        14.0
# 3  Military - German Navy    41.0        21.0
# 4  Military - German Navy    22.0        22.0

# %%
plane_df.to_csv(r'resources\take_3.csv', index = False)
